# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanitha-1111-ART/AI_INTERNSHIP/blob/main/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets,layers,Model
from tensorflow.keras.layers import LSTM,Dense

# %%
mnist=keras.datasets.mnist
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()
train_images,test_images=train_images/255.0,test_images/255.0

# %%
import matplotlib.pyplot as plt
plt.imshow(train_images[123])

# %%
input_shape=(28,28)
inputs =Input(shape=input_shape)
rnn_layer=LSTM(128)(inputs)
outputs=Dense(10,activation='softmax')(rnn_layer)
model=Model(inputs=inputs,outputs=outputs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
h=model.fit(train_images,train_labels,validation_split=0.2,epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 67s 43ms/step - accuracy: 0.8751 - loss: 0.3916 - val_accuracy: 0.9585 - val_loss: 0.1418
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 75s 39ms/step - accuracy: 0.9618 - loss: 0.1255 - val_accuracy: 0.9713 - val_loss: 0.0929
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 55s 37ms/step - accuracy: 0.9747 - loss: 0.0835 - val_accuracy: 0.9738 - val_loss: 0.0867
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 54s 36ms/step - accuracy: 0.9795 - loss: 0.0667 - val_accuracy: 0.9839 - val_loss: 0.0539
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 55s 37ms/step - accuracy: 0.9842 - loss: 0.0522 - val_accuracy: 0.9836 - val_loss: 0.0571

# %%
y_pre=model.predict(test_images)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step

# %%
import numpy as np
yp=np.argmax(y_pre,axis=1)
yp[123]
# Out:
# np.int64(6)
