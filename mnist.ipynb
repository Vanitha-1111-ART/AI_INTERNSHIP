# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanitha-1111-ART/AI_INTERNSHIP/blob/main/mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
mnist=keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train,x_test=x_train/255.0,x_test/255.0

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[1345])

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train[112]
# Out:
# np.uint8(1)

# %%
model=keras.Sequential([layers.Flatten(input_shape=(28,28,1)),
                       layers.Dense(128,activation='relu'),
                       layers.Dense(10,activation='softmax')])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
h = model.fit(x_train,y_train,validation_split=0.2,epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9165 - loss: 0.2932 - val_accuracy: 0.9528 - val_loss: 0.1644
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9609 - loss: 0.1320 - val_accuracy: 0.9633 - val_loss: 0.1243
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9735 - loss: 0.0896 - val_accuracy: 0.9673 - val_loss: 0.1033
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9804 - loss: 0.0665 - val_accuracy: 0.9702 - val_loss: 0.1016
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9845 - loss: 0.0515 - val_accuracy: 0.9706 - val_loss: 0.0966

# %%
y_pred=model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
y_pred[1234]
# Out:
# array([6.2456838e-06, 7.0811287e-02, 2.2948094e-02, 1.7241573e-01,
#        9.5525475e-06, 8.9151911e-02, 3.2260843e-02, 4.7762416e-07,
#        6.1239505e-01, 7.9270734e-07], dtype=float32)

# %%
import numpy as np
yp=np.argmax(y_pred,axis=1)
yp[1234]
# Out:
# np.int64(8)

# %%
print(yp[1234])
# Out:
# 8

# %%
y_test.shape
# Out:
# (10000,)

# %%
test = y_test[333]
pre=yp[333]
plt.title(f'y_test:{test},y_pred:{pre}')
plt.imshow(x_test[333])

# %%
im='/content/mnist-3.0.1.png'

# %%
from PIL import Image
convert = Image.open(im).convert('L')
re=convert.resize((28,28))
print(re)
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x7F01AD3C70E0>

# %%
from PIL import ImageOps
pro=ImageOps.invert(re)

# %%
n=np.array(pro)/255.0

# %%
inp=np.expand_dims(n,axis=0)

# %%
prediction=model.predict(inp)
prdi=np.argmax(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step

# %%
plt.title(f'prediction_number:{prdi}')
plt.imshow(n)

# %%
n.shape
# Out:
# (28, 28)

# %%
model.save("mnist.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
